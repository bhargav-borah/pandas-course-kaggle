# %%
import pandas as pd

pd.set_option('display.max_rows', 100)

# %%
df = pd.read_csv('winemag-data-130k-v2.csv',
                 index_col='Unnamed: 0')

# %%
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
df.rename(columns={'points': 'score'})
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# ...        ...                                                ...
# 7833     Spain  This structured, medium-weight wine's nose off...
# 7834        US  Add this new winery to the growing list of Wal...
#
#                     designation  score  price           province   region_1  \
# 0                  Vulkà Bianco     87    NaN  Sicily & Sardinia       Etna
# 1                      Avidagos     87   15.0              Douro        NaN
# ...                         ...    ...    ...                ...        ...
# 7833  Can Feixes Blanc Selecciò     87   10.0          Catalonia  Catalonia
# 7834                        NaN     87   25.0         Washington        NaN
#
#      region_2    taster_name taster_twitter_handle  \
# 0         NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
df.rename(index={0: 'First Entry',
                 1: 'Second Entry'})
# Out:
#                country                                        description  \
# First Entry      Italy  Aromas include tropical fruit, broom, brimston...
# Second Entry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...                ...                                                ...
# 7833             Spain  This structured, medium-weight wine's nose off...
# 7834                US  Add this new winery to the growing list of Wal...
#
#                             designation  points  price           province  \
# First Entry                Vulkà Bianco      87    NaN  Sicily & Sardinia
# Second Entry                   Avidagos      87   15.0              Douro
# ...                                 ...     ...    ...                ...
# 7833          Can Feixes Blanc Selecciò      87   10.0          Catalonia
# 7834                                NaN      87   25.0         Washington
#
#                region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
df.rename_axis('wines', axis='rows')
# Out:
#         country                                        description  \
# wines
# 0         Italy  Aromas include tropical fruit, broom, brimston...
# 1      Portugal  This is ripe and fruity, a wine that is smooth...
# ...         ...                                                ...
# 7833      Spain  This structured, medium-weight wine's nose off...
# 7834         US  Add this new winery to the growing list of Wal...
#
#                      designation  points  price           province   region_1  \
# wines
# 0                   Vulkà Bianco      87    NaN  Sicily & Sardinia       Etna
# 1                       Avidagos      87   15.0              Douro        NaN
# ...                          ...     ...    ...                ...        ...
# 7833   Can Feixes Blanc Selecciò      87   10.0          Catalonia  Catalonia
# 7834                         NaN      87   25.0         Washington        NaN
#
#       region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %%
df.rename_axis('fields', axis='columns')
# Out:
# fields   country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 7833       Spain  This structured, medium-weight wine's nose off...
# 7834          US  Add this new winery to the growing list of Wal...
#
# fields                designation  points  price           province  \
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                        Avidagos      87   15.0              Douro
# ...                           ...     ...    ...                ...
# 7833    Can Feixes Blanc Selecciò      87   10.0          Catalonia
# 7834                          NaN      87   25.0         Washington
#
# fields   region_1 region_2    taster_name taster_twitter_handle  \
# 0            Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
df.rename_axis('wines', axis='rows').rename_axis('fields', axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 7833       Spain  This structured, medium-weight wine's nose off...
# 7834          US  Add this new winery to the growing list of Wal...
#
# fields                designation  points  price           province  \
# wines
# 0                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                        Avidagos      87   15.0              Douro
# ...                           ...     ...    ...                ...
# 7833    Can Feixes Blanc Selecciò      87   10.0          Catalonia
# 7834                          NaN      87   25.0         Washington
#
# fields   region_1 region_2    taster_name taster_twitter_handle  \
# wines
# ...

# %%
canadian_yt = pd.read_csv('CAvideos.csv')
british_yt = pd.read_csv('GBvideos.csv')

# %%
pd.concat([canadian_yt, british_yt]).shape # default axis=0
# Out:
# (17269, 16)

# %%
canadian_yt.shape[0] + british_yt.shape[0]
# Out:
# 17269

# %%
left = canadian_yt.set_index(['title', 'trending_date'])
right = british_yt.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_GB')
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       n1WpP7iowLc
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       0dBIkQ4Mz1M
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       5qpjK5DgCt4
# I Dare You: GOING BALD!?                           17.14.11       d380meD0W0M
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       2Vv-BfVoq4g
# ...                                                                       ...
# Krampus (2015) KILL COUNT [Capture Count]          17.25.12       R2BWjkQ5MMg
# Machine Gun Kelly - Habits                         17.25.12       hXmBbhGbeo8
# BREAKING NEWS TRUMP 12/23/17: Tucker - Actor Ma... 17.25.12       NBVc9Umt8-s
# 【FULL】欧阳娜娜曾舜晞为爱情争执CP满满 辛芷蕾黄璐再次同台刘敏涛实力对战宋丹丹《演员的诞... 17.25.12       -o6fJAU3WOA
# ...
