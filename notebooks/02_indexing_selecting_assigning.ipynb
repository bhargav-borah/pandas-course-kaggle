# %%
import pandas as pd

pd.set_option('display.max_rows', 5)

# %%
df = pd.read_csv('winemag-data-130k-v2.csv', index_col='Unnamed: 0')

# %%
df
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# ...        ...                                                ...
# 7833     Spain  This structured, medium-weight wine's nose off...
# 7834        US  Add this new winery to the growing list of Wal...
#
#                     designation  points  price           province   region_1  \
# 0                  Vulkà Bianco      87    NaN  Sicily & Sardinia       Etna
# 1                      Avidagos      87   15.0              Douro        NaN
# ...                         ...     ...    ...                ...        ...
# 7833  Can Feixes Blanc Selecciò      87   10.0          Catalonia  Catalonia
# 7834                        NaN      87   25.0         Washington        NaN
#
#      region_2    taster_name taster_twitter_handle  \
# ...

# %%
df.country
# Out:
# 0          Italy
# 1       Portugal
#           ...
# 7833       Spain
# 7834          US
# Name: country, Length: 7835, dtype: object

# %%
df['country']
# Out:
# 0          Italy
# 1       Portugal
#           ...
# 7833       Spain
# 7834          US
# Name: country, Length: 7835, dtype: object

# %%
df['country'][0]
# Out:
# 'Italy'

# %%
df.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
df.iloc[:, 0]
# Out:
# 0          Italy
# 1       Portugal
#           ...
# 7833       Spain
# 7834          US
# Name: country, Length: 7835, dtype: object

# %%
df.iloc[:3, 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
df.iloc[1:3, 0]
# Out:
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
df.iloc[[0, 1, 2], 0]
# Out:
# 0       Italy
# 1    Portugal
# 2          US
# Name: country, dtype: object

# %%
df.iloc[-5:]
# Out:
#         country                                        description  \
# 7830      Italy  This is the first vintage of this wine that wi...
# 7831  Australia  It seems as if the emphasis is more on the oak...
# 7832  Australia  At 93% Shiraz, many wineries would have just l...
# 7833      Spain  This structured, medium-weight wine's nose off...
# 7834         US  Add this new winery to the growing list of Wal...
#
#                     designation  points  price         province  \
# 7830             Campo ai Sasso      87    NaN          Tuscany
# 7831                     Wilgha      87   34.0  South Australia
# 7832                        NaN      87   17.0  South Australia
# 7833  Can Feixes Blanc Selecciò      87   10.0        Catalonia
# 7834                        NaN      87   25.0       Washington
#
#                  region_1 region_2     taster_name taster_twitter_handle  \
# 7830  Rosso di Montalcino      NaN             NaN                   NaN
# ...

# %%
df.tail() == df.iloc[-5:]
# Out:
#       country  description  designation  points  price  province  region_1  \
# 7830     True         True         True    True  False      True      True
# 7831     True         True         True    True   True      True      True
# 7832     True         True        False    True   True      True      True
# 7833     True         True         True    True   True      True      True
# 7834     True         True        False    True   True      True     False
#
#       region_2  taster_name  taster_twitter_handle  title  variety  winery
# 7830     False        False                  False   True     True    True
# 7831     False         True                   True   True     True    True
# 7832     False         True                   True   True     True    True
# 7833     False        False                  False   True     True    True
# 7834     False        False                  False  False    False   False

# %%
import numpy as np

# %%
np.nan == np.nan
# Out:
# False

# %%
df.loc[0, 'country']
# Out:
# 'Italy'

# %%
df.loc[:, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#         taster_name taster_twitter_handle  points
# 0     Kerin O’Keefe          @kerinokeefe      87
# 1        Roger Voss            @vossroger      87
# ...             ...                   ...     ...
# 7833            NaN                   NaN      87
# 7834            NaN                   NaN      87
#
# [7835 rows x 3 columns]

# %%
df.loc[0:5, ['taster_name', 'taster_twitter_handle', 'points']]
# Out:
#           taster_name taster_twitter_handle  points
# 0       Kerin O’Keefe          @kerinokeefe      87
# 1          Roger Voss            @vossroger      87
# ..                ...                   ...     ...
# 4        Paul Gregutt           @paulgwine       87
# 5   Michael Schachner           @wineschach      87
#
# [6 rows x 3 columns]

# %%
df.iloc[0:5, [8, 9, 3]]
# Out:
#           taster_name taster_twitter_handle  points
# 0       Kerin O’Keefe          @kerinokeefe      87
# 1          Roger Voss            @vossroger      87
# 2        Paul Gregutt           @paulgwine       87
# 3  Alexander Peartree                   NaN      87
# 4        Paul Gregutt           @paulgwine       87

# %%
for idx, col in enumerate(df.columns):
  print(idx, col)
# Out:
# 0 country
# 1 description
# 2 designation
# 3 points
# 4 price
# 5 province
# 6 region_1
# 7 region_2
# 8 taster_name
# 9 taster_twitter_handle
# 10 title
# 11 variety
# 12 winery

# %%
df.set_index('title')
# Out:
#                                                      country  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                      Italy
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       Portugal
# ...                                                      ...
# Huguet de Can Feixes 2000 Can Feixes Blanc Sele...     Spain
# NaN                                                       US
#
#                                                                                           description  \
# title
# Nicosia 2013 Vulkà Bianco  (Etna)                   Aromas include tropical fruit, broom, brimston...
# Quinta dos Avidagos 2011 Avidagos Red (Douro)       This is ripe and fruity, a wine that is smooth...
# ...                                                                                               ...
# Huguet de Can Feixes 2000 Can Feixes Blanc Sele...  This structured, medium-weight wine's nose off...
# ...

# %%
df.loc[df.country == 'Italy']
# Out:
#      country                                        description  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 6      Italy  Here's a bright, informal red that opens with ...
# ...      ...                                                ...
# 7804   Italy  Here's a ruby-colored Rosso from Montalcino wi...
# 7830   Italy  This is the first vintage of this wine that wi...
#
#          designation  points  price           province             region_1  \
# 0       Vulkà Bianco      87    NaN  Sicily & Sardinia                 Etna
# 6            Belsito      87   16.0  Sicily & Sardinia             Vittoria
# ...              ...     ...    ...                ...                  ...
# 7804             NaN      87    NaN            Tuscany  Rosso di Montalcino
# 7830  Campo ai Sasso      87    NaN            Tuscany  Rosso di Montalcino
#
#      region_2    taster_name taster_twitter_handle  \
# 0         NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
df[(df.country == 'Italy') | (df.points >= 90)]
# Out:
#      country                                        description  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 6      Italy  Here's a bright, informal red that opens with ...
# ...      ...                                                ...
# 7804   Italy  Here's a ruby-colored Rosso from Montalcino wi...
# 7830   Italy  This is the first vintage of this wine that wi...
#
#          designation  points  price           province             region_1  \
# 0       Vulkà Bianco      87    NaN  Sicily & Sardinia                 Etna
# 6            Belsito      87   16.0  Sicily & Sardinia             Vittoria
# ...              ...     ...    ...                ...                  ...
# 7804             NaN      87    NaN            Tuscany  Rosso di Montalcino
# 7830  Campo ai Sasso      87    NaN            Tuscany  Rosso di Montalcino
#
#      region_2    taster_name taster_twitter_handle  \
# 0         NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
df.loc[(df.country == 'Italy') | (df.points >= 90)]
# Out:
#      country                                        description  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 6      Italy  Here's a bright, informal red that opens with ...
# ...      ...                                                ...
# 7804   Italy  Here's a ruby-colored Rosso from Montalcino wi...
# 7830   Italy  This is the first vintage of this wine that wi...
#
#          designation  points  price           province             region_1  \
# 0       Vulkà Bianco      87    NaN  Sicily & Sardinia                 Etna
# 6            Belsito      87   16.0  Sicily & Sardinia             Vittoria
# ...              ...     ...    ...                ...                  ...
# 7804             NaN      87    NaN            Tuscany  Rosso di Montalcino
# 7830  Campo ai Sasso      87    NaN            Tuscany  Rosso di Montalcino
#
#      region_2    taster_name taster_twitter_handle  \
# 0         NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
df[df.country.isin(['France', 'Italy'])]
# Out:
#      country                                        description  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 6      Italy  Here's a bright, informal red that opens with ...
# ...      ...                                                ...
# 7820  France  Very soft, ripe grapefruit and kumquat flavors...
# 7830   Italy  This is the first vintage of this wine that wi...
#
#          designation  points  price           province             region_1  \
# 0       Vulkà Bianco      87    NaN  Sicily & Sardinia                 Etna
# 6            Belsito      87   16.0  Sicily & Sardinia             Vittoria
# ...              ...     ...    ...                ...                  ...
# 7820  La Charnivolle      87   23.0       Loire Valley        Menetou-Salon
# 7830  Campo ai Sasso      87    NaN            Tuscany  Rosso di Montalcino
#
#      region_2    taster_name taster_twitter_handle  \
# 0         NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
df.loc[df.country.isin(['France', 'Italy'])]
# Out:
#      country                                        description  \
# 0      Italy  Aromas include tropical fruit, broom, brimston...
# 6      Italy  Here's a bright, informal red that opens with ...
# ...      ...                                                ...
# 7820  France  Very soft, ripe grapefruit and kumquat flavors...
# 7830   Italy  This is the first vintage of this wine that wi...
#
#          designation  points  price           province             region_1  \
# 0       Vulkà Bianco      87    NaN  Sicily & Sardinia                 Etna
# 6            Belsito      87   16.0  Sicily & Sardinia             Vittoria
# ...              ...     ...    ...                ...                  ...
# 7820  La Charnivolle      87   23.0       Loire Valley        Menetou-Salon
# 7830  Campo ai Sasso      87    NaN            Tuscany  Rosso di Montalcino
#
#      region_2    taster_name taster_twitter_handle  \
# 0         NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
df[df['price'].notnull()]
# Out:
#        country                                        description  \
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# 2           US  Tart and snappy, the flavors of lime flesh and...
# ...        ...                                                ...
# 7833     Spain  This structured, medium-weight wine's nose off...
# 7834        US  Add this new winery to the growing list of Wal...
#
#                     designation  points  price    province           region_1  \
# 1                      Avidagos      87   15.0       Douro                NaN
# 2                           NaN      87   14.0      Oregon  Willamette Valley
# ...                         ...     ...    ...         ...                ...
# 7833  Can Feixes Blanc Selecciò      87   10.0   Catalonia          Catalonia
# 7834                        NaN      87   25.0  Washington                NaN
#
#                region_2   taster_name taster_twitter_handle  \
# ...

# %%
df.loc[df['price'].notnull()]
# Out:
#        country                                        description  \
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# 2           US  Tart and snappy, the flavors of lime flesh and...
# ...        ...                                                ...
# 7833     Spain  This structured, medium-weight wine's nose off...
# 7834        US  Add this new winery to the growing list of Wal...
#
#                     designation  points  price    province           region_1  \
# 1                      Avidagos      87   15.0       Douro                NaN
# 2                           NaN      87   14.0      Oregon  Willamette Valley
# ...                         ...     ...    ...         ...                ...
# 7833  Can Feixes Blanc Selecciò      87   10.0   Catalonia          Catalonia
# 7834                        NaN      87   25.0  Washington                NaN
#
#                region_2   taster_name taster_twitter_handle  \
# ...

# %%
df['critic'] = 'everyone'

# %%
df
# Out:
#        country                                        description  \
# 0        Italy  Aromas include tropical fruit, broom, brimston...
# 1     Portugal  This is ripe and fruity, a wine that is smooth...
# ...        ...                                                ...
# 7833     Spain  This structured, medium-weight wine's nose off...
# 7834        US  Add this new winery to the growing list of Wal...
#
#                     designation  points  price           province   region_1  \
# 0                  Vulkà Bianco      87    NaN  Sicily & Sardinia       Etna
# 1                      Avidagos      87   15.0              Douro        NaN
# ...                         ...     ...    ...                ...        ...
# 7833  Can Feixes Blanc Selecciò      87   10.0          Catalonia  Catalonia
# 7834                        NaN      87   25.0         Washington        NaN
#
#      region_2    taster_name taster_twitter_handle  \
# ...

# %%
df['index_backwards'] = range(len(df), 0, -1)

# %%
df.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
df.shape
# Out:
# (7835, 15)
